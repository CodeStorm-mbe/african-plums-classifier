# %%
# Installation des dépendances principales
# !pip install torch torchvision pytorch-lightning albumentations timm wandb kaggle idx2numpy

# Installation des dépendances pour le prétraitement des données
# !pip install pandas matplotlib seaborn scikit-learn pillow

# Installation des dépendances pour la visualisation
# !pip install plotly opencv-python
# !pip install torchmetrics


# Vérification de l'installation de CUDA (pour le GPU)
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA disponible: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Nombre de GPUs: {torch.cuda.device_count()}")
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 35.5 MB/s eta 0:00:00
# ...

# %%
# Importer les modules
from data_preprocessing_adapted import DataPreprocessor, KaggleDatasetDownloader
from model_classification_adapted import PlumClassifier, ModelTrainer
from training_pipeline_adapted import PlumClassificationPipeline

# Configurer et exécuter le pipeline
pipeline = PlumClassificationPipeline(
    base_dir='/content/plum_classifier',
    kaggle_dataset='arnaudfadja/african-plums-quality-and-defect-assessment-data',
    use_wandb=False
)

# Exécuter le pipeline complet
results = pipeline.run_pipeline()

# Afficher les résultats
print(f"Modèle sauvegardé à: {results['model_path']}")
print(f"Modèle ONNX exporté à: {results['onnx_path']}")
# Out:
# Téléchargement du dataset arnaudfadja/african-plums-quality-and-defect-assessment-data...
# Dataset URL: https://www.kaggle.com/datasets/arnaudfadja/african-plums-quality-and-defect-assessment-data
# Extraction du dataset dans /content/plum_classifier/data/extracted/african-plums-quality-and-defect-assessment-data...
# Téléchargement du dataset zalando-research/fashionmnist...
# Dataset URL: https://www.kaggle.com/datasets/zalando-research/fashionmnist
# Extraction du dataset dans /content/plum_classifier/data/extracted/fashionmnist...
# Téléchargement du dataset puneet6060/intel-image-classification...
# Dataset URL: https://www.kaggle.com/datasets/puneet6060/intel-image-classification
# Extraction du dataset dans /content/plum_classifier/data/extracted/intel-image-classification...
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:87: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
# ...
